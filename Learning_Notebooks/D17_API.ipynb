# %% [markdown]
# ---
# ### Fetching Data from API
#
# #### Using real world dataset from WHO at GHO (The Global Health Observatory) Website.

# %% [markdown]
# Importing data from API directly
# - json viewer is used online to see the format of original API Json structure.
# - `req` stores API container, `.json` converts it to json format, and we choose 'value' key to see results.
# - `display.max_colwidth` is set to None so that any values in IndicatorName column are not truncated

# %%
import requests as rq
import pandas as pd

request = rq.get('https://ghoapi.azureedge.net/api/Indicator')
df = pd.DataFrame(request.json()['value'])
pd.set_option('display.max_colwidth', None)

# %%
df[df['IndicatorName'] == 'Life expectancy at birth (years)']
# Out:
#       IndicatorCode                     IndicatorName Language
# 1788  WHOSIS_000001  Life expectancy at birth (years)       EN

# %%
df[df['IndicatorName'].str.contains('Under-five mortality rate', case=False, na=False)]
# Out:
#        IndicatorCode  \
# 1375            u5mr
# 2848  MDG_0000000007
#
#                                                                        IndicatorName  \
# 1375                         Under-five mortality rate (deaths per 1000 live births)
# 2848  Under-five mortality rate (probability of dying by age 5 per 1000 live births)
#
#      Language
# 1375       EN
# 2848       EN

# %%
df[df['IndicatorName'].str.contains('maternal mortality ratio', case=False, na=False)]
# Out:
#        IndicatorCode  \
# 2090  MDG_0000000032
# 2341  MDG_0000000026
#
#                                                                         IndicatorName  \
# 2090  Maternal mortality ratio (per 100 000 live births) - Country reported estimates
# 2341                               Maternal mortality ratio (per 100 000 live births)
#
#      Language
# 2090       EN
# 2341       EN

# %%
df[df['IndicatorName'].str.contains('physicians', case=False, na=False)]
# Out:
#                      IndicatorCode  \
# 76                          HRH_02
# 254                         HRH_26
# 872                     GDO_q6x2_1
# 2276  PRISON_B9_1_PHYSICIANS_RATIO
#
#                                                            IndicatorName  \
# 76                                                  Number of physicians
# 254                             Physicians density (per 1000 population)
# 872   Inclusion of basic dementia competencies in training of physicians
# 2276                     Physicians in prisons (FTEs per 1000 prisoners)
#
#      Language
# 76         EN
# 254        EN
# 872        EN
# 2276       EN

# %%
df[df['IndicatorName'].str.contains('hospital beds', case=False, na=False)]
# Out:
#      IndicatorCode                                             IndicatorName  \
# 1116    GDO_q9x1_4  Geriatric-specific hospital beds (per 10,000 population)
# 1144    GDO_q9x1_3   Dementia-specific hospital beds (per 10,000 population)
# 1927      WHS6_102                     Hospital beds (per 10 000 population)
#
#      Language
# 1116       EN
# 1144       EN
# 1927       EN

# %%
df[df['IndicatorName'].str.contains('gdp', case=False, na=False)]
# Out:
#                IndicatorCode  \
# 307              GB_XPD_RSDV
# 730             R_afford_gdp
# 1257  GHED_GGHE-DGDP_SHA2011
# 1343     GHED_CHEGDP_SHA2011
# 2399       TAXBEV_AFFORD_GDP
#
#                                                                                                   IndicatorName  \
# 307                                       Research and development (R&amp;D) expenditure as a proportion of GDP
# 730    Affordability - percentage of GDP per capita required to purchase 2000 cigarettes of the most sold brand
# 1257  Domestic general government health expenditure (GGHE-D) as percentage of gross domestic product (GDP) (%)
# 1343                         Current health expenditure (CHE) as percentage of gross domestic product (GDP) (%)
# 2399                                                        GDP per capita to purchase a volume of beverage (%)
#
#      Language
# 307        EN
# 730        EN
# 1257       EN
# 1343       EN
# 2399       EN

# %%
df
# Out:
#                           IndicatorCode  \
# 0                                AIR_10
# 1                                AIR_12
# 2                                AIR_16
# 3                                 AIR_3
# 4                                AIR_35
# ...                                 ...
# 3051                      SA_0000001844
# 3052                       UHCTRANSFATS
# 3053   HEPATITIS_HBV_INFECTIONS_NEW_NUM
# 3054  PHE_HHAIR_PROP_POP_CATEGORY_FUELS
# 3055                        E_compl_e11
#
#                                                                                                IndicatorName  \
# 0                               Ambient air pollution  attributable DALYs per 100'000 children under 5 years
# 1                                      Household air pollution attributable deaths in children under 5 years
# 2                                       Household air pollution attributable DALYs in children under 5 years
# 3                                  Percentage of the total population living in cities > 100'000 inhabitants
# 4                                                         Joint effects of air pollution attributable deaths
# ...                                                                                                      ...
# 3051                                              Alcohol-attributable all-cause deaths (all ages), (number)
# 3052                Best-practice policy implemented for industrially produced trans-fatty acids (TFA) (Y/N)
# 3053                                                       New chronic hepatitis B (HBV) infections (number)
# 3054  Proportion of population with primary reliance on fuels and technologies for cooking, by fuel type (%)
# 3055             Compliance with ban on use of brand name of non-tobacco product for tobacco product (score)
#
#      Language
# 0          EN
# 1          EN
# 2          EN
# 3          EN
# 4          EN
# ...       ...
# 3051       EN
# 3052       EN
# 3053       EN
# 3054       EN
# 3055       EN
#
# [3056 rows x 3 columns]

# %%
codes = ['WHOSIS_000001' , 'u5mr' , 'MDG_0000000026' , 'HRH_26' , 'WHS6_102']
df = df[df['IndicatorCode'].isin(codes)]
df
# Out:
#        IndicatorCode                                            IndicatorName  \
# 254           HRH_26                 Physicians density (per 1000 population)
# 1375            u5mr  Under-five mortality rate (deaths per 1000 live births)
# 1788   WHOSIS_000001                         Life expectancy at birth (years)
# 1927        WHS6_102                    Hospital beds (per 10 000 population)
# 2341  MDG_0000000026       Maternal mortality ratio (per 100 000 live births)
#
#      Language
# 254        EN
# 1375       EN
# 1788       EN
# 1927       EN
# 2341       EN

# %%
# for i in range(len(codes)):
#     code = codes[i]

request = rq.get('https://ghoapi.azureedge.net/api/WHOSIS_000001')
d = pd.DataFrame(request.json()['value'])
d.head()
# Out:
#         Id  IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0  9387322  WHOSIS_000001        COUNTRY        OMN        YEAR
# 1  9388527  WHOSIS_000001        COUNTRY        BLZ        YEAR
# 2  9388585  WHOSIS_000001        COUNTRY        GIN        YEAR
# 3  9389231  WHOSIS_000001        COUNTRY        NZL        YEAR
# 4  9390603  WHOSIS_000001        COUNTRY        IRL        YEAR
#
#   ParentLocationCode         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0                EMR  Eastern Mediterranean      SEX     2003   SEX_MLE  ...
# 1                AMR               Americas      SEX     2003  SEX_FMLE  ...
# 2                AFR                 Africa      SEX     2016  SEX_FMLE  ...
# 3                WPR        Western Pacific      SEX     2018  SEX_BTSX  ...
# 4                EUR                 Europe      SEX     2003  SEX_BTSX  ...
#
#   DataSourceDim             Value NumericValue        Low       High Comments  \
# 0          None  70.3 [69.7-71.1]    70.316239  69.707280  71.131767     None
# 1          None  74.7 [74.5-75.0]    74.727983  74.533552  74.955545     None
# 2          None  61.1 [60.1-62.0]    61.095901  60.113522  62.005773     None
# 3          None  81.8 [81.7-81.8]    81.755405  81.727056  81.842149     None
# 4          None  78.0 [78.0-78.1]    78.023793  78.003415  78.129261     None
#
#                             Date  TimeDimensionValue  \
# 0  2024-08-02T09:43:39.193+02:00                2003
# 1  2024-08-02T09:43:39.193+02:00                2003
# 2  2024-08-02T09:43:39.193+02:00                2016
# 3  2024-08-02T09:43:39.193+02:00                2018
# 4  2024-08-02T09:43:39.193+02:00                2003
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  2003-01-01T00:00:00+01:00  2003-12-31T00:00:00+01:00
# 1  2003-01-01T00:00:00+01:00  2003-12-31T00:00:00+01:00
# 2  2016-01-01T00:00:00+01:00  2016-12-31T00:00:00+01:00
# 3  2018-01-01T00:00:00+01:00  2018-12-31T00:00:00+01:00
# 4  2003-01-01T00:00:00+01:00  2003-12-31T00:00:00+01:00
#
# [5 rows x 25 columns]

# %%
d['SpatialDim'].unique()
# Out:
# array(['OMN', 'BLZ', 'GIN', 'NZL', 'IRL', 'TZA', 'ZAF', 'NER', 'SLV',
#        'CPV', 'BLR', 'BGD', 'RUS', 'TON', 'CYP', 'SYC', 'GBR', 'KAZ',
#        'ARE', 'GRC', 'GTM', 'BOL', 'AFR', 'SLB', 'GRD', 'DOM', 'DEU',
#        'PRK', 'SRB', 'PRT', 'MNG', 'POL', 'WPR', 'UZB', 'AUT', 'PRY',
#        'VCT', 'CAF', 'SAU', 'WB_UMI', 'FIN', 'NOR', 'LBR', 'PAK', 'HRV',
#        'WB_LMI', 'USA', 'WB_HI', 'SWZ', 'DJI', 'NGA', 'TJK', 'ERI', 'BHR',
#        'LKA', 'DZA', 'WSM', 'DNK', 'MLT', 'JAM', 'GUY', 'BRN', 'IRQ',
#        'QAT', 'EST', 'MAR', 'TKM', 'VNM', 'LVA', 'CHL', 'MEX', 'PRI',
#        'AGO', 'SEAR', 'GHA', 'ROU', 'NIC', 'BGR', 'AZE', 'CHN', 'FJI',
#        'PER', 'CHE', 'LAO', 'MOZ', 'SSD', 'TGO', 'CUB', 'BHS', 'GEO',
#        'LSO', 'LUX', 'PNG', 'AMR', 'URY', 'PAN', 'MDA', 'LTU', 'KOR',
#        'SLE', 'HND', 'SVK', 'GLOBAL', 'EMR', 'PHL', 'IDN', 'LCA', 'GMB',
#        'ECU', 'NAM', 'BDI', 'VEN', 'KIR', 'BTN', 'FRA', 'TUR', 'SUR',
#        'TLS', 'ETH', 'MWI', 'YEM', 'MYS', 'UKR', 'BRA', 'BIH', 'EGY',
#        'GNQ', 'BRB', 'ATG', 'SYR', 'MUS', 'UGA', 'IND', 'NLD', 'ARM',
#        'FSM', 'PSE', 'WB_LI', 'HUN', 'CZE', 'EUR', 'TTO', 'COL', 'GNB',
#        'CIV', 'TCD', 'KWT', 'MKD', 'COD', 'STP', 'ARG', 'MDV', 'ZWE',
#        'ESP', 'AUS', 'SVN', 'BEN', 'LBY', 'MRT', 'THA', 'ISR', 'CMR',
#        'KHM', 'KGZ', 'COM', 'GAB', 'SGP', 'NPL', 'MMR', 'RWA', 'ISL',
#        'SEN', 'JOR', 'BWA', 'TUN', 'CAN', 'SOM', 'COG', 'IRN', 'AFG',
#        'JPN', 'HTI', 'BFA', 'CRI', 'KEN', 'SWE', 'LBN', 'BEL', 'ALB',
#        'ZMB', 'VUT', 'MDG', 'ITA', 'MNE', 'SDN', 'MLI'], dtype=object)

# %% [markdown]
# Need to do same thing for each Indicator. find their SpatialDim, TimeDim, value of indicator. Then merge all indicators year and country wise to form a real dataset that can be worked upon.
#
# This tutorial was for learning API basics and the objective is achieved.
#
# - This dataset can be completed and be uploaded to kaggle or be used to create a model later.
# ## To Be Continued...
